# %%
# !py --version
# Out:
# Python 3.10.8

# %% [markdown]
# # deleted the cache

# %%
# from huggingface_hub import scan_cache_dir
# scan_cache_dir().delete_revisions()

# %%
from transformers import LayoutLMv3Processor, LayoutLMv3ForTokenClassification
import torch 
from paddleocr import PaddleOCR
import paddle
import pprint
import numpy as np
from PIL import Image
# Out:
# D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# No model hoster is available! Please check your network connection to one of the following model hoster: HuggingFace (https://huggingface.co), ModelScope (https://modelscope.cn), AIStudio (https://aistudio.baidu.com), or BOS (https://paddle-model-ecology.bj.bcebos.com). Otherwise, only local models can be used.
# D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)

# %%
gpu_or_cpu="cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(gpu_or_cpu) #used to set the model to run in cpu or cuda 

print("Using device:", device)

model = LayoutLMv3ForTokenClassification.from_pretrained("microsoft/layoutlmv3-base")
processor = LayoutLMv3Processor.from_pretrained("microsoft/layoutlmv3-base",apply_ocr=False)

# Move model to GPU
model.to(device)
# Out:
# Using device: cuda
# Loading weights:   0%|          | 0/212 [00:00<?, ?it/s]
# LayoutLMv3ForTokenClassification LOAD REPORT from: microsoft/layoutlmv3-base
# Key                                | Status     |
# -----------------------------------+------------+-
# layoutlmv3.embeddings.position_ids | UNEXPECTED |
# classifier.weight                  | MISSING    |
# classifier.bias                    | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\processing_utils.py:965, in ProcessorMixin.get_processor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     963 try:
#     964     # Load from local folder or from cache or download from model Hub and cache
# --> 965     resolved_processor_file = cached_file(
#     966         pretrained_model_name_or_path,
#     967         processor_file,
#     968         cache_dir=cache_dir,
#     969         force_download=force_download,
#     970         proxies=proxies,
#     971         local_files_only=local_files_only,
#     972         token=token,
#     973         user_agent=user_agent,
#     974         revision=revision,
#     975         subfolder=subfolder,
#     976         _raise_exceptions_for_missing_entries=False,
#     977     )
#     979     # chat_template.json is a legacy file used by the processor class
#     980     # a raw chat_template.jinja is preferred in future
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\utils\hub.py:277, in cached_file(path_or_repo_id, filename, **kwargs)
#     227 """
#     228 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     229
#    (...)
#     275 ```
#     276 """
# --> 277 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     278 file = file[0] if file is not None else file
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\utils\hub.py:508, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     507     elif not isinstance(e, EntryNotFoundError):
# --> 508         raise e
#     510 resolved_files = [
#     511     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     512 ]
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\utils\hub.py:420, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     418 if len(full_filenames) == 1:
#     419     # This is slightly better for only 1 file
# --> 420     hf_hub_download(
#     421         path_or_repo_id,
#     422         filenames[0],
#     423         subfolder=None if len(subfolder) == 0 else subfolder,
#     424         repo_type=repo_type,
#     425         revision=revision,
#     426         cache_dir=cache_dir,
#     427         user_agent=user_agent,
#     428         force_download=force_download,
#     429         proxies=proxies,
#     430         token=token,
#     431         local_files_only=local_files_only,
#     432     )
#     433 else:
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\file_download.py:986, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     985 else:
# --> 986     return _hf_hub_download_to_cache_dir(
#     987         # Destination
#     988         cache_dir=cache_dir,
#     989         # File info
#     990         repo_id=repo_id,
#     991         filename=filename,
#     992         repo_type=repo_type,
#     993         revision=revision,
#     994         # HTTP info
#     995         endpoint=endpoint,
#     996         etag_timeout=etag_timeout,
#     997         headers=hf_headers,
#     998         token=token,
#     999         # Additional options
#    1000         local_files_only=local_files_only,
#    1001         force_download=force_download,
#    1002         tqdm_class=tqdm_class,
#    1003         dry_run=dry_run,
#    1004     )
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\file_download.py:1119, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1117         logger.info("No local file found. Retrying..")
#    1118         (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = (
# -> 1119             _get_metadata_or_catch_error(
#    1120                 repo_id=repo_id,
#    1121                 filename=filename,
#    1122                 repo_type=repo_type,
#    1123                 revision=revision,
#    1124                 endpoint=endpoint,
#    1125                 etag_timeout=_ETAG_RETRY_TIMEOUT,
#    1126                 headers=headers,
#    1127                 token=token,
#    1128                 local_files_only=local_files_only,
#    1129                 storage_folder=storage_folder,
#    1130                 relative_filename=relative_filename,
#    1131                 retry_on_errors=True,
#    1132             )
#    1133         )
#    1135 # If still error, raise
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\file_download.py:1653, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors)
#    1652 try:
# -> 1653     metadata = get_hf_file_metadata(
#    1654         url=url,
#    1655         timeout=etag_timeout,
#    1656         headers=headers,
#    1657         token=token,
#    1658         endpoint=endpoint,
#    1659         retry_on_errors=retry_on_errors,
#    1660     )
#    1661 except RemoteEntryNotFoundError as http_error:
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\utils\_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\file_download.py:1576, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1575 # Retrieve metadata
# -> 1576 response = _httpx_follow_relative_redirects_with_backoff(
#    1577     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1578 )
#    1579 hf_raise_for_status(response)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\utils\_http.py:685, in _httpx_follow_relative_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     684 while True:
# --> 685     response = http_backoff(
#     686         method=method,
#     687         url=url,
#     688         **httpx_kwargs,
#     689         follow_redirects=False,
#     690         **no_retry_kwargs,
#     691     )
#     692     hf_raise_for_status(response)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\utils\_http.py:559, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     505 """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     506
#     507 Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)
#     557 > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     558 """
# --> 559 return next(
#     560     _http_backoff_base(
#     561         method=method,
#     562         url=url,
#     563         max_retries=max_retries,
#     564         base_wait_time=base_wait_time,
#     565         max_wait_time=max_wait_time,
#     566         retry_on_exceptions=retry_on_exceptions,
#     567         retry_on_status_codes=retry_on_status_codes,
#     568         stream=False,
#     569         **kwargs,
#     570     )
#     571 )
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\huggingface_hub\utils\_http.py:467, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     466 else:
# --> 467     response = client.request(method=method, url=url, **kwargs)
#     468     if not _should_retry(response):
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\httpx\_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     900 if self._state == ClientState.CLOSED:
# --> 901     raise RuntimeError("Cannot send a request, as the client has been closed.")
#     903 self._state = ClientState.OPENED
#
# RuntimeError: Cannot send a request, as the client has been closed.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 7
#       4 print("Using device:", device)
#       6 model = LayoutLMv3ForTokenClassification.from_pretrained("microsoft/layoutlmv3-base")
# ----> 7 processor = LayoutLMv3Processor.from_pretrained("microsoft/layoutlmv3-base",apply_ocr=False)
#       9 # Move model to GPU
#      10 model.to(device)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\processing_utils.py:1402, in ProcessorMixin.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#    1399     kwargs["token"] = token
#    1401 # Get processor_dict first so we can use it to instantiate non-tokenizer sub-processors
# -> 1402 processor_dict, instantiation_kwargs = cls.get_processor_dict(pretrained_model_name_or_path, **kwargs)
#    1403 args = cls._get_arguments_from_pretrained(pretrained_model_name_or_path, processor_dict, **kwargs)
#    1404 return cls.from_args_and_dict(args, processor_dict, **instantiation_kwargs)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\transformers\processing_utils.py:1045, in ProcessorMixin.get_processor_dict(cls, pretrained_model_name_or_path, **kwargs)
#    1042         raise
#    1043     except Exception:
#    1044         # For any other exception, we throw a generic error.
# -> 1045         raise OSError(
#    1046             f"Can't load processor for '{pretrained_model_name_or_path}'. If you were trying to load"
#    1047             " it from 'https://huggingface.co/models', make sure you don't have a local directory with the"
#    1048             f" same name. Otherwise, make sure '{pretrained_model_name_or_path}' is the correct path to a"
#    1049             f" directory containing a {PROCESSOR_NAME} file"
#    1050         )
#    1052 # Add chat template as kwarg before returning because most models don't have processor config
#    1053 if resolved_chat_template_file is not None:
#    1054     # This is the legacy path
#
# OSError: Can't load processor for 'microsoft/layoutlmv3-base'. If you were trying to load it from 'https://huggingface.co/models', make sure you don't have a local directory with the same name. Otherwise, make sure 'microsoft/layoutlmv3-base' is the correct path to a directory containing a processor_config.json file

# %%
image_path = "./training data/1.jpg"

# %%
print(paddle.device.get_device())
ocr = PaddleOCR(use_textline_orientation=True, lang='en', device='gpu')
result = ocr.predict(image_path)

# %%
# pprint.pprint(result)

# %%
# result

# %%
# pprint.pprint(len(result[0]["rec_texts"]))
# pprint.pprint(result[0]["rec_texts"])

# %%
# pprint.pprint(len(result[0]["rec_polys"]))
# pprint.pprint(result[0]["rec_polys"])

# %%
# pprint.pprint(result[0]["rec_texts"][0])
# pprint.pprint(result[0]["rec_polys"][0])

# print(result[0]["rec_polys"][0][:])
poly=result[0]["rec_polys"][0][:]

# %%
# to get the max and min points 
def getMinMaxPoint(poly):
    x0 = int(poly[:,0].min())
    y0 = int(poly[:,1].min())
    x1 = int(poly[:,0].max())
    y1 = int(poly[:,1].max())
    return [x0, y0, x1, y1] 

# print(getMinMaxPoint(poly))
 # the rectangle for the **entire line**

# %%
pprint.pprint(result[0]["rec_texts"][0].split())
# a=result[0]["rec_texts"][0].split()

# print(len(a[0].strip()))

# print(result[0]["rec_texts"][0])
# print(len(result[0]["rec_texts"][0]))
# print(len(a[0]),len(a[1]))

# %%
token_word=[]
token_poly=[]

# %%
# xy_points=getMinMaxPoint(poly)
# sentence= result[0]["rec_texts"][0]
# sentence_split = result[0]["rec_texts"][0].split()

def tokenize_sent(xy_points, sentence_split, sentence):
    print(len(sentence))
    letter_width=(xy_points[2]-xy_points[0])/len(sentence)
    x = xy_points[0]
    y0, y1 = xy_points[1], xy_points[3]

    for i, word in enumerate(sentence_split):
        word_width = len(word) * letter_width
        x_end = x + word_width

        # print([int(x), y0, int(x_end), y1])
        token_word.append(word)
        token_poly.append([int(x), y0, int(x_end), y1])
        x = x_end

        # add space after word (except last)
        if i < len(sentence_split) - 1:
            x += letter_width


print(tokenize_sent(xy_points,sentence_split,sentence))

# %%
# token_word
# token_poly

# %%
for i,(box,word) in enumerate(zip(result[0]["rec_polys"],result[0]["rec_texts"])):
    if len(word) == 0:
        continue  
    points_max_min=getMinMaxPoint(box[:])
    tokenize_sent(points_max_min,word.split(),word)
    print('index: ',i,word)
    # print(box[:],word)

# %%
len(token_word)
# token_word

# %%
len(token_poly)
# token_poly

# %%
image = Image.open(image_path).convert("RGB")
width, height = image.size
print(width,height)

# %%
boxes=[]
def normalize(token_ploy, width, height):
    for box in token_ploy:
        boxes.append([
            int(1000 * box[0] / width),
            int(1000 * box[1] / height),
            int(1000 * box[2] / width),
            int(1000 * box[3] / height),
            ])
normalize(token_poly,width,height)

# %%
pprint.pprint(boxes)

# %%
image = Image.open(image_path).convert("RGB")

# %%
encoding = processor(
    images=image,
    text=token_word,
    boxes=boxes,
    return_tensors="pt",
    padding="max_length",
    truncation=True
)

# %%
# Move tensors to the same device as model
for k, v in encoding.items():
    encoding[k] = v.to(device)

# %%
# Get predictions
outputs = model(**encoding)
# print(outputs)
# The model outputs logits for each token
logits = outputs.logits  # shape: [batch_size, seq_len, num_labels]
print(logits)
# Get predicted class for each token
predictions = torch.argmax(logits, dim=-1)
# print(predictions)

# %%
# Suppose your model has these label mappings
labels = model.config.id2label

predicted_labels = [labels[p.item()] for p in predictions[0][:len(token_word)]]

for token_word, label in zip(token_word, predicted_labels):
    print(token_word, "->", label)
