# %%
# !py --version
# Out:
# Python 3.10.8

# %% [markdown]
# # import lib

# %%
# !python -m pip install paddlepaddle==3.2.0 -i https://www.paddlepaddle.org.cn/packages/stable/cpu/                    
# !python -m pip install "paddleocr[all]"                           
# !pip install torch transformers                                      
# !python -m pip install label-studio
# Out:
# Looking in indexes: https://www.paddlepaddle.org.cn/packages/stable/cpu/
# Requirement already satisfied: paddlepaddle==3.2.0 in .\.venv\lib\site-packages (3.2.0)
# Requirement already satisfied: httpx in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (0.28.1)
# Requirement already satisfied: numpy>=1.21 in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (2.2.6)
# Requirement already satisfied: protobuf>=3.20.2 in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (6.33.4)
# Requirement already satisfied: Pillow in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (12.1.0)
# Requirement already satisfied: opt-einsum==3.3.0 in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (3.3.0)
# Requirement already satisfied: networkx in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (3.4.2)
# Requirement already satisfied: typing-extensions in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (4.15.0)
# Requirement already satisfied: safetensors>=0.6.0 in .\.venv\lib\site-packages (from paddlepaddle==3.2.0) (0.7.0)
# Requirement already satisfied: anyio in .\.venv\lib\site-packages (from httpx->paddlepaddle==3.2.0) (4.12.1)
# Requirement already satisfied: certifi in .\.venv\lib\site-packages (from httpx->paddlepaddle==3.2.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx->paddlepaddle==3.2.0) (1.0.9)
# Requirement already satisfied: idna in .\.venv\lib\site-packages (from httpx->paddlepaddle==3.2.0) (3.11)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx->paddlepaddle==3.2.0) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\.venv\lib\site-packages (from anyio->httpx->paddlepaddle==3.2.0) (1.3.1)
# Requirement already satisfied: paddleocr[all] in .\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: paddlex<3.5.0,>=3.4.0 in .\.venv\lib\site-packages (from paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (3.4.2)
# Requirement already satisfied: PyYAML>=6 in .\.venv\lib\site-packages (from paddleocr[all]) (6.0.2)
# Requirement already satisfied: requests in .\.venv\lib\site-packages (from paddleocr[all]) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.12 in .\.venv\lib\site-packages (from paddleocr[all]) (4.15.0)
# Requirement already satisfied: aistudio-sdk>=0.3.5 in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.3.8)
# Requirement already satisfied: chardet in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (7.0.1)
# Requirement already satisfied: colorlog in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (6.10.1)
# Requirement already satisfied: filelock in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (3.25.0)
# Requirement already satisfied: huggingface-hub in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.6.0)
# Requirement already satisfied: modelscope>=1.28.0 in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.34.0)
# Requirement already satisfied: numpy>=1.24 in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.2.6)
# Requirement already satisfied: packaging in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (25.0)
# Requirement already satisfied: pandas>=1.3 in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.3.3)
# Requirement already satisfied: pillow in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (12.1.0)
# Requirement already satisfied: prettytable in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (3.17.0)
# Requirement already satisfied: py-cpuinfo in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (9.0.0)
# Requirement already satisfied: pydantic>=2 in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.12.5)
# Requirement already satisfied: ruamel.yaml in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.19.1)
# Requirement already satisfied: ujson in .\.venv\lib\site-packages (from paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (5.11.0)
# Requirement already satisfied: ftfy in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (6.3.1)
# Requirement already satisfied: imagesize in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.0.0)
# Requirement already satisfied: langchain<1.0,>=0.2 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.3.28)
# Requirement already satisfied: langchain-community<1.0,>=0.2 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.3.31)
# Requirement already satisfied: langchain-core in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.3.83)
# Requirement already satisfied: langchain-openai<1.0,>=0.1 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.3.35)
# Requirement already satisfied: lxml in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (6.0.2)
# Requirement already satisfied: openai>=1.63 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.109.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (4.10.0.84)
# Requirement already satisfied: openpyxl in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.1.5)
# Requirement already satisfied: premailer in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.10.0)
# Requirement already satisfied: pyclipper in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.4.0)
# Requirement already satisfied: pypdfium2>=4 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (5.5.0)
# Requirement already satisfied: scikit-learn in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.7.2)
# Requirement already satisfied: scipy in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.15.3)
# Requirement already satisfied: shapely in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.1.2)
# Requirement already satisfied: tokenizers>=0.19 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.22.2)
# Requirement already satisfied: beautifulsoup4 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (4.14.3)
# Requirement already satisfied: python-docx in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.2.0)
# Requirement already satisfied: einops in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.8.2)
# Requirement already satisfied: Jinja2 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.1.6)
# Requirement already satisfied: python-bidi in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.6.7)
# Requirement already satisfied: regex in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2026.2.28)
# Requirement already satisfied: safetensors>=0.7.0 in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.7.0)
# Requirement already satisfied: sentencepiece in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.2.1)
# Requirement already satisfied: tiktoken in .\.venv\lib\site-packages (from paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.12.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in .\.venv\lib\site-packages (from langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.3.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in .\.venv\lib\site-packages (from langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.7.14)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in .\.venv\lib\site-packages (from langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.0.48)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in .\.venv\lib\site-packages (from langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\.venv\lib\site-packages (from langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\.venv\lib\site-packages (from langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in .\.venv\lib\site-packages (from langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in .\.venv\lib\site-packages (from langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in .\.venv\lib\site-packages (from langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\.venv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\lib\site-packages (from langchain-core->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\lib\site-packages (from langchain-core->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.25.0)
# Requirement already satisfied: anyio in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (4.12.1)
# Requirement already satisfied: certifi in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.0.9)
# Requirement already satisfied: idna in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.11)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\lib\site-packages (from openai>=1.63->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\.venv\lib\site-packages (from openai>=1.63->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.13.0)
# Requirement already satisfied: sniffio in .\.venv\lib\site-packages (from openai>=1.63->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\.venv\lib\site-packages (from openai>=1.63->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (4.67.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic>=2->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\lib\site-packages (from pydantic>=2->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\lib\site-packages (from pydantic>=2->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in .\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests->paddleocr[all]) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests->paddleocr[all]) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\.venv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0,>=0.2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.1.0)
# Requirement already satisfied: psutil in .\.venv\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (7.2.2)
# Requirement already satisfied: bce-python-sdk in .\.venv\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.9.63)
# Requirement already satisfied: click in .\.venv\lib\site-packages (from aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (8.3.1)
# Requirement already satisfied: setuptools in .\.venv\lib\site-packages (from modelscope>=1.28.0->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (82.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\lib\site-packages (from huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in .\.venv\lib\site-packages (from huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.3.2)
# Requirement already satisfied: typer in .\.venv\lib\site-packages (from huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.24.1)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm>4->openai>=1.63->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.4.6)
# Requirement already satisfied: pycryptodome>=3.8.0 in .\.venv\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (3.23.0)
# Requirement already satisfied: future>=0.6.0 in .\.venv\lib\site-packages (from bce-python-sdk->aistudio-sdk>=0.3.5->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.0.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\lib\site-packages (from beautifulsoup4->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.8.3)
# Requirement already satisfied: wcwidth in .\.venv\lib\site-packages (from ftfy->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (0.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from Jinja2->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.0.3)
# Requirement already satisfied: et-xmlfile in .\.venv\lib\site-packages (from openpyxl->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.0.0)
# Requirement already satisfied: cssselect in .\.venv\lib\site-packages (from premailer->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.4.0)
# Requirement already satisfied: cssutils in .\.venv\lib\site-packages (from premailer->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (2.11.1)
# Requirement already satisfied: cachetools in .\.venv\lib\site-packages (from premailer->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (7.0.3)
# Requirement already satisfied: more-itertools in .\.venv\lib\site-packages (from cssutils->premailer->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (10.8.0)
# Requirement already satisfied: joblib>=1.2.0 in .\.venv\lib\site-packages (from scikit-learn->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in .\.venv\lib\site-packages (from scikit-learn->paddlex[genai-client,ie,ocr,trans]<3.5.0,>=3.4.0; extra == "all"->paddleocr[all]) (3.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\lib\site-packages (from typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\.venv\lib\site-packages (from typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\lib\site-packages (from typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->paddlex<3.5.0,>=3.4.0->paddlex[ocr-core]<3.5.0,>=3.4.0->paddleocr[all]) (0.1.2)
# Requirement already satisfied: torch in .\.venv\lib\site-packages (2.5.1+cu121)
# Requirement already satisfied: transformers in .\.venv\lib\site-packages (5.3.0)
# Requirement already satisfied: filelock in .\.venv\lib\site-packages (from torch) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in .\.venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in .\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in .\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in .\.venv\lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: sympy==1.13.1 in .\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in .\.venv\lib\site-packages (from transformers) (1.6.0)
# Requirement already satisfied: numpy>=1.17 in .\.venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in .\.venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in .\.venv\lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\.venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in .\.venv\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in .\.venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in .\.venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in .\.venv\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\.venv\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Requirement already satisfied: label-studio in .\.venv\lib\site-packages (1.22.0)
# Requirement already satisfied: Django<5.2.0,>=5.1.8 in .\.venv\lib\site-packages (from label-studio) (5.1.15)
# Requirement already satisfied: appdirs>=1.4.3 in .\.venv\lib\site-packages (from label-studio) (1.4.4)
# Requirement already satisfied: attr==0.3.1 in .\.venv\lib\site-packages (from label-studio) (0.3.1)
# Requirement already satisfied: attrs>=19.2.0 in .\.venv\lib\site-packages (from label-studio) (25.4.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in .\.venv\lib\site-packages (from label-studio) (12.28.0)
# Requirement already satisfied: bleach<5.1.0,>=5.0.0 in .\.venv\lib\site-packages (from label-studio) (5.0.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28.58 in .\.venv\lib\site-packages (from label-studio) (1.42.63)
# Requirement already satisfied: botocore<2.0.0,>=1.39.3 in .\.venv\lib\site-packages (from label-studio) (1.42.63)
# Requirement already satisfied: colorama>=0.4.4 in .\.venv\lib\site-packages (from label-studio) (0.4.6)
# Requirement already satisfied: cryptography>=44.0.1 in .\.venv\lib\site-packages (from label-studio) (46.0.5)
# Requirement already satisfied: defusedxml>=0.7.1 in .\.venv\lib\site-packages (from label-studio) (0.7.1)
# Requirement already satisfied: django-annoying==0.10.6 in .\.venv\lib\site-packages (from label-studio) (0.10.6)
# Requirement already satisfied: django-cors-headers==4.7.0 in .\.venv\lib\site-packages (from label-studio) (4.7.0)
# Requirement already satisfied: django-csp==3.7 in .\.venv\lib\site-packages (from label-studio) (3.7)
# Requirement already satisfied: django-debug-toolbar==3.2.1 in .\.venv\lib\site-packages (from label-studio) (3.2.1)
# Requirement already satisfied: django-environ==0.10.0 in .\.venv\lib\site-packages (from label-studio) (0.10.0)
# Requirement already satisfied: django-extensions==3.2.3 in .\.venv\lib\site-packages (from label-studio) (3.2.3)
# Requirement already satisfied: django-filter==24.3 in .\.venv\lib\site-packages (from label-studio) (24.3)
# Requirement already satisfied: django-migration-linter<6.0.0,>=5.1.0 in .\.venv\lib\site-packages (from label-studio) (5.2.0)
# Requirement already satisfied: django-model-utils==4.1.1 in .\.venv\lib\site-packages (from label-studio) (4.1.1)
# Requirement already satisfied: django-ranged-fileresponse>=0.1.2 in .\.venv\lib\site-packages (from label-studio) (0.1.2)
# Requirement already satisfied: django-rq<3.2,>=3.1 in .\.venv\lib\site-packages (from label-studio) (3.1)
# Requirement already satisfied: django-storages==1.12.3 in .\.venv\lib\site-packages (from label-studio) (1.12.3)
# Requirement already satisfied: django-user-agents==0.4.0 in .\.venv\lib\site-packages (from label-studio) (0.4.0)
# Requirement already satisfied: djangorestframework==3.15.2 in .\.venv\lib\site-packages (from label-studio) (3.15.2)
# Requirement already satisfied: djangorestframework-simplejwt<6.0.0,>=5.4.0 in .\.venv\lib\site-packages (from djangorestframework-simplejwt[crypto]<6.0.0,>=5.4.0->label-studio) (5.5.1)
# Requirement already satisfied: drf-dynamic-fields==0.3.0 in .\.venv\lib\site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: drf-flex-fields==0.9.5 in .\.venv\lib\site-packages (from label-studio) (0.9.5)
# Requirement already satisfied: drf-generators==0.3.0 in .\.venv\lib\site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: drf-spectacular==0.28.0 in .\.venv\lib\site-packages (from label-studio) (0.28.0)
# Requirement already satisfied: google-cloud-logging<4.0.0,>=3.10.0 in .\.venv\lib\site-packages (from label-studio) (3.14.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.13.0 in .\.venv\lib\site-packages (from label-studio) (2.19.0)
# Requirement already satisfied: ijson<4.0.0,>=3.4.0 in .\.venv\lib\site-packages (from label-studio) (3.5.0)
# Requirement already satisfied: label-studio-sdk==2.0.16 in .\.venv\lib\site-packages (from label-studio) (2.0.16)
# Requirement already satisfied: launchdarkly-server-sdk==8.2.1 in .\.venv\lib\site-packages (from label-studio) (8.2.1)
# Requirement already satisfied: lockfile>=0.12.0 in .\.venv\lib\site-packages (from label-studio) (0.12.2)
# Requirement already satisfied: lxml>=4.9.4 in .\.venv\lib\site-packages (from lxml[html-clean]>=4.9.4->label-studio) (6.0.2)
# Requirement already satisfied: numpy<3.0.0,>=2.2.6 in .\.venv\lib\site-packages (from label-studio) (2.2.6)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in .\.venv\lib\site-packages (from label-studio) (1.109.1)
# Requirement already satisfied: ordered-set==4.0.2 in .\.venv\lib\site-packages (from label-studio) (4.0.2)
# Requirement already satisfied: pandas>=2.2.3 in .\.venv\lib\site-packages (from label-studio) (2.3.3)
# Requirement already satisfied: psycopg<4.0.0,>=3.2.0 in .\.venv\lib\site-packages (from psycopg[binary]<4.0.0,>=3.2.0->label-studio) (3.3.3)
# Requirement already satisfied: pyarrow<23.0.0,>=22.0.0 in .\.venv\lib\site-packages (from label-studio) (22.0.0)
# Requirement already satisfied: pyboxen>=1.3.0 in .\.venv\lib\site-packages (from label-studio) (1.3.0)
# Requirement already satisfied: pydantic>=2.9.2 in .\.venv\lib\site-packages (from label-studio) (2.12.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in .\.venv\lib\site-packages (from label-studio) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.4 in .\.venv\lib\site-packages (from label-studio) (2.0.4)
# Requirement already satisfied: pytz<2023.0,>=2022.1 in .\.venv\lib\site-packages (from label-studio) (2022.7.1)
# Requirement already satisfied: pyyaml>=6.0.0 in .\.venv\lib\site-packages (from label-studio) (6.0.2)
# Requirement already satisfied: redis<5.3.0,>=5.2.1 in .\.venv\lib\site-packages (from label-studio) (5.2.1)
# Requirement already satisfied: requests<2.33.0,>=2.32.3 in .\.venv\lib\site-packages (from label-studio) (2.32.5)
# Requirement already satisfied: rq<2.7,>=2.6 in .\.venv\lib\site-packages (from label-studio) (2.6.1)
# Requirement already satisfied: rules==3.4 in .\.venv\lib\site-packages (from label-studio) (3.4)
# Requirement already satisfied: sentry-sdk>=2.16.0 in .\.venv\lib\site-packages (from label-studio) (2.54.0)
# Requirement already satisfied: setuptools>=75.4.0 in .\.venv\lib\site-packages (from label-studio) (82.0.0)
# Requirement already satisfied: tldextract>=5.1.3 in .\.venv\lib\site-packages (from label-studio) (5.3.1)
# Requirement already satisfied: ujson>=3.0.0 in .\.venv\lib\site-packages (from label-studio) (5.11.0)
# Requirement already satisfied: uuid-utils<1.0.0,>=0.11.0 in .\.venv\lib\site-packages (from label-studio) (0.14.1)
# Requirement already satisfied: wheel<=0.40.0,>=0.38.1 in .\.venv\lib\site-packages (from label-studio) (0.40.0)
# Requirement already satisfied: xmljson==0.2.1 in .\.venv\lib\site-packages (from label-studio) (0.2.1)
# Requirement already satisfied: six in .\.venv\lib\site-packages (from django-annoying==0.10.6->label-studio) (1.17.0)
# Requirement already satisfied: asgiref>=3.6 in .\.venv\lib\site-packages (from django-cors-headers==4.7.0->label-studio) (3.11.1)
# Requirement already satisfied: sqlparse>=0.2.0 in .\.venv\lib\site-packages (from django-debug-toolbar==3.2.1->label-studio) (0.5.5)
# Requirement already satisfied: user-agents in .\.venv\lib\site-packages (from django-user-agents==0.4.0->label-studio) (2.2.0)
# Requirement already satisfied: uritemplate>=2.0.0 in .\.venv\lib\site-packages (from drf-spectacular==0.28.0->label-studio) (4.2.0)
# Requirement already satisfied: jsonschema>=2.6.0 in .\.venv\lib\site-packages (from drf-spectacular==0.28.0->label-studio) (4.26.0)
# Requirement already satisfied: inflection>=0.3.1 in .\.venv\lib\site-packages (from drf-spectacular==0.28.0->label-studio) (0.5.1)
# Requirement already satisfied: Pillow>=11.3.0 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (12.1.0)
# Requirement already satisfied: datamodel-code-generator==0.26.1 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (0.26.1)
# Requirement already satisfied: httpx>=0.21.2 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (0.28.1)
# Requirement already satisfied: jsf<0.12.0,>=0.11.2 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (0.11.2)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (3.9.3)
# Requirement already satisfied: opencv-python-headless<5.0.0,>=4.12.0 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (4.13.0.92)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (2.41.5)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (2.11.0)
# Requirement already satisfied: requests-mock==1.12.1 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (1.12.1)
# Requirement already satisfied: typing_extensions>=4.0.0 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (4.15.0)
# Requirement already satisfied: urllib3>=2.5.0 in .\.venv\lib\site-packages (from label-studio-sdk==2.0.16->label-studio) (2.6.3)
# Requirement already satisfied: argcomplete<4.0,>=1.10 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (3.6.3)
# Requirement already satisfied: black>=19.10b0 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (26.3.0)
# Requirement already satisfied: genson<2.0,>=1.2.1 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (1.3.0)
# Requirement already satisfied: inflect<6.0,>=4.1.0 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (5.6.2)
# Requirement already satisfied: isort<6.0,>=4.3.21 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (5.13.2)
# Requirement already satisfied: jinja2<4.0,>=2.10.1 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (3.1.6)
# Requirement already satisfied: packaging in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (25.0)
# Requirement already satisfied: toml<1.0.0,>=0.10.0 in .\.venv\lib\site-packages (from datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (0.10.2)
# Requirement already satisfied: certifi>=2018.4.16 in .\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (2026.1.4)
# Requirement already satisfied: expiringdict>=1.1.4 in .\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (1.2.2)
# Requirement already satisfied: pyRFC3339>=1.0 in .\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (2.1.0)
# Requirement already satisfied: semver>=2.10.2 in .\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (3.0.4)
# Requirement already satisfied: webencodings in .\.venv\lib\site-packages (from bleach<5.1.0,>=5.0.0->label-studio) (0.5.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in .\.venv\lib\site-packages (from boto3<2.0.0,>=1.28.58->label-studio) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in .\.venv\lib\site-packages (from boto3<2.0.0,>=1.28.58->label-studio) (0.16.0)
# Requirement already satisfied: tzdata in .\.venv\lib\site-packages (from Django<5.2.0,>=5.1.8->label-studio) (2025.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in .\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.30.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.49.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.8.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.4.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.0.0 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.5.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.14.3)
# Requirement already satisfied: opentelemetry-api>=1.9.0 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.40.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.78.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.27.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in .\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (6.33.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in .\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in .\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.78.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in .\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (4.9.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in .\.venv\lib\site-packages (from google-cloud-storage<3.0.0,>=2.13.0->label-studio) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in .\.venv\lib\site-packages (from google-cloud-storage<3.0.0,>=2.13.0->label-studio) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2<4.0,>=2.10.1->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (3.0.3)
# Requirement already satisfied: faker>=15.3.4 in .\.venv\lib\site-packages (from jsf<0.12.0,>=0.11.2->label-studio-sdk==2.0.16->label-studio) (40.8.0)
# Requirement already satisfied: rstr>=3.2.0 in .\.venv\lib\site-packages (from jsf<0.12.0,>=0.11.2->label-studio-sdk==2.0.16->label-studio) (3.2.2)
# Requirement already satisfied: smart-open>=6.3.0 in .\.venv\lib\site-packages (from smart-open[http]>=6.3.0->jsf<0.12.0,>=0.11.2->label-studio-sdk==2.0.16->label-studio) (7.5.1)
# Requirement already satisfied: click in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->label-studio-sdk==2.0.16->label-studio) (8.3.1)
# Requirement already satisfied: joblib in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->label-studio-sdk==2.0.16->label-studio) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->label-studio-sdk==2.0.16->label-studio) (2026.2.28)
# Requirement already satisfied: tqdm in .\.venv\lib\site-packages (from nltk<4.0.0,>=3.9.1->label-studio-sdk==2.0.16->label-studio) (4.67.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (0.13.0)
# Requirement already satisfied: sniffio in .\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.10.0->label-studio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in .\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.10.0->label-studio) (3.11)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx>=0.21.2->label-studio-sdk==2.0.16->label-studio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->label-studio-sdk==2.0.16->label-studio) (0.16.0)
# Requirement already satisfied: psycopg-binary==3.3.3 in .\.venv\lib\site-packages (from psycopg[binary]<4.0.0,>=3.2.0->label-studio) (3.3.3)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\lib\site-packages (from pydantic>=2.9.2->label-studio) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\lib\site-packages (from pydantic>=2.9.2->label-studio) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in .\.venv\lib\site-packages (from pydantic[email]!=2.4.0,<3.0,>=1.9.0; python_version >= "3.10" and python_version < "3.11"->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (2.3.0)
# Requirement already satisfied: async-timeout>=4.0.3 in .\.venv\lib\site-packages (from redis<5.3.0,>=5.2.1->label-studio) (4.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests<2.33.0,>=2.32.3->label-studio) (3.4.5)
# Requirement already satisfied: croniter in .\.venv\lib\site-packages (from rq<2.7,>=2.6->label-studio) (6.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in .\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.6.2)
# Requirement already satisfied: azure-core>=1.30.0 in .\.venv\lib\site-packages (from azure-storage-blob>=12.6.0->label-studio) (1.38.2)
# Requirement already satisfied: isodate>=0.6.1 in .\.venv\lib\site-packages (from azure-storage-blob>=12.6.0->label-studio) (0.7.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in .\.venv\lib\site-packages (from black>=19.10b0->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in .\.venv\lib\site-packages (from black>=19.10b0->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in .\.venv\lib\site-packages (from black>=19.10b0->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (4.9.4)
# Requirement already satisfied: pytokens~=0.4.0 in .\.venv\lib\site-packages (from black>=19.10b0->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (0.4.1)
# Requirement already satisfied: tomli>=1.1.0 in .\.venv\lib\site-packages (from black>=19.10b0->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (2.4.0)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\lib\site-packages (from cryptography>=44.0.1->label-studio) (2.0.0)
# Requirement already satisfied: pycparser in .\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.1->label-studio) (3.0)
# Requirement already satisfied: dnspython>=2.0.0 in .\.venv\lib\site-packages (from email-validator>=2.0.0->pydantic[email]!=2.4.0,<3.0,>=1.9.0; python_version >= "3.10" and python_version < "3.11"->datamodel-code-generator==0.26.1->label-studio-sdk==2.0.16->label-studio) (2.8.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\lib\site-packages (from jsonschema>=2.6.0->drf-spectacular==0.28.0->label-studio) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\lib\site-packages (from jsonschema>=2.6.0->drf-spectacular==0.28.0->label-studio) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\lib\site-packages (from jsonschema>=2.6.0->drf-spectacular==0.28.0->label-studio) (0.30.0)
# Requirement already satisfied: lxml_html_clean in .\.venv\lib\site-packages (from lxml[html-clean]>=4.9.4->label-studio) (0.4.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in .\.venv\lib\site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in .\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (3.23.0)
# Requirement already satisfied: rich>=12.5.1 in .\.venv\lib\site-packages (from pyboxen>=1.3.0->label-studio) (14.3.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\lib\site-packages (from rich>=12.5.1->pyboxen>=1.3.0->label-studio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\lib\site-packages (from rich>=12.5.1->pyboxen>=1.3.0->label-studio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.5.1->pyboxen>=1.3.0->label-studio) (0.1.2)
# Requirement already satisfied: wrapt in .\.venv\lib\site-packages (from smart-open>=6.3.0->smart-open[http]>=6.3.0->jsf<0.12.0,>=0.11.2->label-studio-sdk==2.0.16->label-studio) (2.1.2)
# Requirement already satisfied: requests-file>=1.4 in .\.venv\lib\site-packages (from tldextract>=5.1.3->label-studio) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in .\.venv\lib\site-packages (from tldextract>=5.1.3->label-studio) (3.25.0)
# Requirement already satisfied: ua-parser>=0.10.0 in .\.venv\lib\site-packages (from user-agents->django-user-agents==0.4.0->label-studio) (1.0.1)
# Requirement already satisfied: ua-parser-builtins in .\.venv\lib\site-packages (from ua-parser>=0.10.0->user-agents->django-user-agents==0.4.0->label-studio) (202603)

# %% [markdown]
# # using paddleocr to get text and position of text
# ## save it in json file

# %%
import json

from paddleocr import PaddleOCR

import os
os.environ["PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK"] = "True"


ocr = PaddleOCR(
    use_doc_orientation_classify=False, 
    use_doc_unwarping=False, 
    use_textline_orientation=False) # text detection + text recognition



image_path = "./training data/1.jpg"


result = ocr.predict(image_path) # predict the image
for res in result:
    res.print() # print the result of each image
    # res.save_to_img("output")
    res.save_to_json("output/paddle_ocr_result.json")

# %% [markdown]
# # json file ref label studio formate

# %% [raw]
# {
#   "id": 10,
#   "data": {
#     "ocr": "http://localhost:8080/1.jpg"
#   },
#   "annotations": [],
#   "predictions": [
#     {
#       "id": 4,
#       "result": [
#         {
#           "original_width": 864,
#           "original_height": 1296,
#           "image_rotation": 0,
#           "value": {
#             "x": 48.9333,
#             "y": 61.3336,
#             "width": 9.73333,
#             "height": 2.8446,
#             "rotation": 0
#           },
#           "id": "bb1",
#           "from_name": "bbox",
#           "to_name": "image",
#           "type": "rectangle"
#         },
#         {
#           "original_width": 864,
#           "original_height": 1296,
#           "image_rotation": 0,
#           "value": {
#             "x": 48.9333,
#             "y": 61.3336,
#             "width": 9.7333,
#             "height": 2.8446,
#             "rotation": 0,
#             "labels": [
#               "Text"
#             ]
#           },
#           "id": "bb1",
#           "from_name": "label",
#           "to_name": "image",
#           "type": "labels"
#         },
#         {
#           "original_width": 864,
#           "original_height": 1296,
#           "image_rotation": 0,
#           "value": {
#             "x": 48.9333,
#             "y": 61.3336,
#             "width": 9.7333,
#             "height": 2.8446,
#             "rotation": 0,
#             "text": [
#               "TOTAL"
#             ]
#           },
#           "id": "bb1",
#           "from_name": "transcription",
#           "to_name": "image",
#           "type": "textarea"
#         }
#       ],
#       "model_version": "best_ocr_model_1_final",
#       "created_ago": "1 day",
#       "score": 0.89,
#       "cluster": null,
#       "neighbors": null,
#       "mislabeling": 0,
#       "created_at": "2026-03-09T20:02:29.559293Z",
#       "updated_at": "2026-03-09T20:02:29.559293Z",
#       "model": null,
#       "model_run": null,
#       "task": 10,
#       "project": 20
#     }
#   ]
# }

# %% [markdown]
# # converting ocr output to label studio output

# %%
import json

def convert_ocr_to_ls(ocr_json, image_url, img_w, img_h):

    results = []

    polys = ocr_json["rec_polys"]
    texts = ocr_json["rec_texts"]

    for i, poly in enumerate(polys):

        xs = [p[0] for p in poly]
        ys = [p[1] for p in poly]

        x_min = min(xs)
        y_min = min(ys)

        x_max = max(xs)
        y_max = max(ys)

        w = x_max - x_min
        h = y_max - y_min

        results.append({
            "id": f"box_{i}",
            "type": "rectangle",
            "from_name": "bbox",
            "to_name": "image",
            "original_width": img_w,
            "original_height": img_h,
            "image_rotation": 0,
            "value": {
                "x": x_min/img_w*100,
                "y": y_min/img_h*100,
                "width": w/img_w*100,
                "height": h/img_h*100,
                "rotation": 0
            }
        })
        
        # OCR Text
        results.append({
            "id": f"box_{i}",
            "type": "textarea",
            "from_name": "transcription",
            "to_name": "image",
            "value": {
                "text": [texts[i]]
            }
        })
        
    return {
        "data": {
            "ocr": image_url
        },
        "predictions":[
            {
                "model_version":"paddleocr",
                "result": results
            }
        ]
    }

data=convert_ocr_to_ls(res, "http://localhost:8000/output/1.jpg", 2232, 3300)
print(data)
                       
# with open("./output/paddle_ocr_result.json", "r") as f:
#     data = json.load(f)
#     print(data.get('ocr'))
with open("output/labelstudio_tasks.json", "w") as f:
    json.dump(data, f, indent=4)

# %%
import json
import pprint
with open("output/labelstudio_output.json", 'r') as f:
    data = json.load(f)
pprint.pprint(data)

# %%
for task in data:
    annotations = task.get("annotations", [])
    print(annotation)

# %%
import json


# Load your Label Studio JSON
with open("output/labelstudio_output.json", 'r') as f:
    data = json.load(f)

    

def normalize_bbox(x, y, width, height):
    """
    Convert % bbox → LayoutLM format (0–1000)
    """
    x1 = int(x * 10)
    y1 = int(y * 10)
    x2 = int((x + width) * 10)
    y2 = int((y + height) * 10)
    print("bbox")
    return [x1, y1, x2, y2]
    


def convert_label(label):
    """
    Convert labels to BIO format
    """
    print("label")
    if label.lower() == "ignore":
        return "O"
    return label.upper()

# %%
final_dataset = []

for task in data:
    print(1)
    print(task["label"][0]["labels"][0])
    annotations = task["label"][0]["labels"][0]
    if not annotations:
        continue
    print(annotations)
    results = annotations["label"]

    words = []
    bboxes = []
    labels = []
    print(3)



    
    for item in results:
        print(4)
        if item["type"] != "labels":
            continue

        value = item["value"]

        # Extract data
        text = value.get("text", "")
        x = value.get("x", 0)
        y = value.get("y", 0)
        width = value.get("width", 0)
        height = value.get("height", 0)
        label = value.get("labels", ["O"])[0]

        # Split words
        tokens = text.split()

        # Convert bbox
        bbox = normalize_bbox(x, y, width, height)

        # Assign BIO labels
        for i, token in enumerate(tokens):
            words.append(token)
            bboxes.append(bbox)

            if label.lower() == "ignore":
                labels.append("O")
            else:
                if i == 0:
                    labels.append(f"B-{label.upper()}")
                else:
                    labels.append(f"I-{label.upper()}")

    final_dataset.append({
        "words": words,
        "bboxes": bboxes,
        "labels": labels
    })

# %%
# Save cleaned dataset
with open("layoutlm_dataset.json", "w") as f:
    json.dump(final_dataset, f, indent=4)


print("✅ Dataset ready for LayoutLMv3 training!")

# %%
# !pip install transformers datasets pillow torchvision
# Out:
# Requirement already satisfied: transformers in .\.venv\lib\site-packages (5.3.0)
# Requirement already satisfied: datasets in .\.venv\lib\site-packages (4.8.3)
# Requirement already satisfied: pillow in .\.venv\lib\site-packages (12.1.0)
# Requirement already satisfied: torchvision in .\.venv\lib\site-packages (0.20.1+cu121)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in .\.venv\lib\site-packages (from transformers) (1.6.0)
# Requirement already satisfied: numpy>=1.17 in .\.venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in .\.venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in .\.venv\lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\.venv\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in .\.venv\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in .\.venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in .\.venv\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in .\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in .\.venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in .\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in .\.venv\lib\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in .\.venv\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in .\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in .\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in .\.venv\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in .\.venv\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in .\.venv\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: torch==2.5.1+cu121 in .\.venv\lib\site-packages (from torchvision) (2.5.1+cu121)
# Requirement already satisfied: networkx in .\.venv\lib\site-packages (from torch==2.5.1+cu121->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in .\.venv\lib\site-packages (from torch==2.5.1+cu121->torchvision) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in .\.venv\lib\site-packages (from torch==2.5.1+cu121->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.venv\lib\site-packages (from sympy==1.13.1->torch==2.5.1+cu121->torchvision) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2->torch==2.5.1+cu121->torchvision) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in .\.venv\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\.venv\lib\site-packages (from typer->transformers) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)

# %%
import torch
from transformers import LayoutLMv3Tokenizer, LayoutLMv3ForTokenClassification
from paddleocr import PaddleOCR
from PIL import Image
from torchvision import transforms
# Out:
# D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.

# %%
! setx CUDA_HOME "C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.8"
! setx PATH "C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.8\bin;%PATH%"
# Out:
# SUCCESS: Specified value was saved.
#
# SUCCESS: Specified value was saved.
# WARNING: The data being saved is truncated to 1024 characters.

# %%
# ---------------------------
# 1. Setup
# ---------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = LayoutLMv3Tokenizer.from_pretrained("microsoft/layoutlmv3-base")
model = LayoutLMv3ForTokenClassification.from_pretrained("microsoft/layoutlmv3-base")

import torch
print(torch.cuda.is_available())  # Should print True
print(torch.cuda.get_device_name(0))  # Shows GPU name

model.to(device)
model.eval()

ocr = PaddleOCR(use_gpu=True, lang='en')
# ocr = PaddleOCR(use_textline_orientation=True, lang='en')  # GPU if configured
# Out:
# Loading weights:   0%|          | 0/212 [00:00<?, ?it/s]
# LayoutLMv3ForTokenClassification LOAD REPORT from: microsoft/layoutlmv3-base
# Key                                | Status     |
# -----------------------------------+------------+-
# layoutlmv3.embeddings.position_ids | UNEXPECTED |
# classifier.bias                    | MISSING    |
# classifier.weight                  | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# True
# NVIDIA GeForce RTX 4050 Laptop GPU
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 16
#      13 model.to(device)
#      14 model.eval()
# ---> 16 ocr = PaddleOCR(use_gpu=True, lang='en')
#      17 # ocr = PaddleOCR(use_textline_orientation=True, lang='en')  # GPU if configured
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\paddleocr\_pipelines\ocr.py:163, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, return_word_box, text_rec_input_shape, lang, ocr_version, **kwargs)
#     159         base_params[name] = val
#     161 self._params = params
# --> 163 super().__init__(**base_params)
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\paddleocr\_pipelines\base.py:63, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      61 super().__init__()
#      62 self._paddlex_config = paddlex_config
# ---> 63 self._common_args = parse_common_args(
#      64     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      65 )
#      66 self._merged_paddlex_config = self._get_merged_paddlex_config()
#      67 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File D:\Anuj_S_Jain\Data\Code\Project\Society_MCE_QT\Society_MCE\Prototype\.venv\lib\site-packages\paddleocr\_common_args.py:45, in parse_common_args(kwargs, default_enable_hpi)
#      43 unknown_names = kwargs.keys() - default_vals.keys()
#      44 for name in unknown_names:
# ---> 45     raise ValueError(f"Unknown argument: {name}")
#      47 kwargs = {**default_vals, **kwargs}
#      49 if kwargs["precision"] not in SUPPORTED_PRECISION_LIST:
#
# ValueError: Unknown argument: use_gpu

# %%
# cheking is paddle ocr has gpu
# !python -m pip install paddlepaddle-gpu
import paddle
gpu_available  = paddle.device.is_compiled_with_cuda()
print("GPU available:", gpu_available)

# %%
print(next(model.parameters()).device)
inputa = inputa.to(device)

print(inputa['input_ids'].device)
# !pip uninstall torch torchvision torchaudio
# Out:
# cuda:0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print(next(model.parameters()).device)
# ----> 2 inputa = inputs.to(device)
#       4 print(inputa['input_ids'].device)
#       5 # !pip uninstall torch torchvision torchaudio
#
# NameError: name 'inputs' is not defined

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
